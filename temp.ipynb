# %%
# open csv with pandas
import pandas as pd
import numpy as np
file = 'temp.csv'

f = pd.read_csv(file, header=None,)
# delete cols with NaN
f = f.dropna(axis=1).round(3)

# %%
f
# Out:
#       0      1      2      3      5      6      7      8      10     11  \
# 0  0.881  0.742  0.550  0.319  0.840  0.681  0.592  0.248  0.859  0.708
# 1  0.017  0.015  0.061  0.060  0.037  0.013  0.024  0.064  0.023  0.033
# 2  0.867  0.703  0.561  0.256  0.859  0.718  0.586  0.269  0.888  0.709
# 3  0.041  0.057  0.060  0.061  0.019  0.015  0.011  0.036  0.013  0.058
# 4  0.835  0.643  0.082  0.275  0.802  0.591  0.191  0.241  0.808  0.618
# 5  0.008  0.024  0.027  0.025  0.007  0.022  0.021  0.021  0.004  0.023
# 6  0.811  0.605  0.118  0.246  0.769  0.585  0.162  0.241  0.824  0.580
# 7  0.015  0.025  0.042  0.021  0.022  0.014  0.019  0.013  0.008  0.019
#
#       12     13     15     16     17     18     20     21     22     23
# 0  0.598  0.256  0.852  0.710  0.603  0.273  0.851  0.733  0.620  0.290
# 1  0.045  0.043  0.029  0.036  0.024  0.029  0.032  0.035  0.020  0.060
# 2  0.487  0.260  0.893  0.690  0.485  0.236  0.802  0.649  0.546  0.185
# ...

# %%
for i in range(4):
    
    print('| Fine-Tuning Method | Raw Accuracy | AUROC | F1 | AUPRC |')
    print('| --- | --- | --- | --- | --- |')
    
    mean = f.loc[i*2].to_numpy()
    sd = f.loc[i*2+1].to_numpy()

    j = 0
    str = ' | Finetune | '
    for k in range(4):
        str += f'{mean[j*4+k]} &pm; {sd[j*4+k]} | '
    print(str)
    
    j = 1
    str = ' | LoRA | '
    for k in range(4):
        str += f'{mean[j*4+k]} &pm; {sd[j*4+k]} | '
    print(str)   
     
    j = 2
    str = ' | Generalized Prompt Tuning | '
    for k in range(4):
        str += f'{mean[j*4+k]} &pm; {sd[j*4+k]} | '
    print(str)            

    j = 3
    str = ' | Prompt Tuning | '
    for k in range(4):
        str += f'{mean[j*4+k]} &pm; {sd[j*4+k]} | '
    print(str) 
    
    j = 4
    str = ' | Linear Probing | '
    for k in range(4):
        str += f'{mean[j*4+k]} &pm; {sd[j*4+k]} | '
    print(str)     
    
    print('\n')
# Out:
# | Fine-Tuning Method | Raw Accuracy | AUROC | F1 | AUPRC |
# | --- | --- | --- | --- | --- |
#  | Finetune | 0.881 &pm; 0.017 | 0.742 &pm; 0.015 | 0.55 &pm; 0.061 | 0.319 &pm; 0.06 |
#  | LoRA | 0.84 &pm; 0.037 | 0.681 &pm; 0.013 | 0.592 &pm; 0.024 | 0.248 &pm; 0.064 |
#  | Generalized Prompt Tuning | 0.859 &pm; 0.023 | 0.708 &pm; 0.033 | 0.598 &pm; 0.045 | 0.256 &pm; 0.043 |
#  | Prompt Tuning | 0.852 &pm; 0.029 | 0.71 &pm; 0.036 | 0.603 &pm; 0.024 | 0.273 &pm; 0.029 |
#  | Linear Probing | 0.851 &pm; 0.032 | 0.733 &pm; 0.035 | 0.62 &pm; 0.02 | 0.29 &pm; 0.06 |
#
#
# | Fine-Tuning Method | Raw Accuracy | AUROC | F1 | AUPRC |
# | --- | --- | --- | --- | --- |
#  | Finetune | 0.867 &pm; 0.041 | 0.703 &pm; 0.057 | 0.561 &pm; 0.06 | 0.256 &pm; 0.061 |
#  | LoRA | 0.859 &pm; 0.019 | 0.718 &pm; 0.015 | 0.586 &pm; 0.011 | 0.269 &pm; 0.036 |
#  | Generalized Prompt Tuning | 0.888 &pm; 0.013 | 0.709 &pm; 0.058 | 0.487 &pm; 0.023 | 0.26 &pm; 0.046 |
# ...

# %%
input = '''
0.900	0.601	0.474	0.159
0.000	0.039	0.000	0.039
'''

# %%
# split by newline, then by whitespace
input.split('\n')
# Out:
# ['', '0.900\t0.601\t0.474\t0.159', '0.000\t0.039\t0.000\t0.039', '']

# %%
means = input.split('\n')[1]
sds = input.split('\n')[2]
for i in range(4):
    print(f'{means.split()[i]} &pm; {sds.split()[i]} | ', end='')
# Out:
# 0.900 &pm; 0.000 | 0.601 &pm; 0.039 | 0.474 &pm; 0.000 | 0.159 &pm; 0.039 |

# %%
input = '''
46	42	32	38	43
7	7	6	29	31
1218	1025	418	706	1048
130	119	107	430	581
1287	1084	421	697	1114
137	124	112	432	567
'''

# %%
input = input.split('\n')
input
# Out:
# ['',
#  '46\t42\t32\t38\t43',
#  '7\t7\t6\t29\t31',
#  '1218\t1025\t418\t706\t1048',
#  '130\t119\t107\t430\t581',
#  '1287\t1084\t421\t697\t1114',
#  '137\t124\t112\t432\t567',
#  '']

# %%
for j in range(6):
    inp = input[j+1]
    for i in range(5):
        print(f'{inp.split()[i]} | ', end='')
    print('\n')
# Out:
# 46 | 42 | 32 | 38 | 43 |
#
# 7 | 7 | 6 | 29 | 31 |
#
# 1218 | 1025 | 418 | 706 | 1048 |
#
# 130 | 119 | 107 | 430 | 581 |
#
# 1287 | 1084 | 421 | 697 | 1114 |
#
# 137 | 124 | 112 | 432 | 567 |

# %%
list = [
    "0.872666667	0.685186197	0.523053938	0.270895795 " + "0.841333333	0.683250492	0.579079693	0.236746105 " + " 0.856	0.728666085	0.628662476	0.271610951" + " 0.852	0.719075046	0.622520076	0.289938163" + " 0.86	0.736590085	0.606062127	0.287699909",
    "0.032482474	0.036889607	0.047452356	0.055648972 " + "0.013920409	0.049001931	0.019973054	0.049622265" + " 0.018547237	0.038406533	0.01056379	0.032241049		0.020504742	0.043969101	0.017734251	0.045897136		0.03190263	0.033212177	0.011324911	0.034571712",
    "0.862666667	0.735755148	0.614590122	0.296185644		0.854666667	0.718118916	0.587438496	0.250364394		0.891333333	0.697099795	0.471246453	0.236088319		0.892	0.681927903	0.47747349	0.244475971		0.796	0.711866125	0.588424166	0.259234035",
    "0.032276582	0.018700824	0.056791572	0.053617184		0.026381812	0.01997275	0.017672865	0.032302587		0.013266499	0.04450865	0.003709312	0.044488068		0.013432961	0.055141418	0.013271879	0.025410615		0.060567685	0.026569753	0.033743056	0.035628108",
    "0.59496	0.635400876	0.29474819	0.266463572 " + "0.741813333	0.597967195	0.258901442	0.243291986" + " 0.68224	0.620819816	0.293085768	0.258212695		0.697146667	0.624949195	0.293100049	0.262012124		0.639573333	0.636611428	0.283918643	0.266598895",
    "0.041605931	0.019894206	0.018032303	0.018344008 " + "0.011855006	0.018994988	0.028165188	0.020809417	" + "0.019148524	0.028185623	0.022307014	0.029058905		0.007456946	0.020815142	0.016595497	0.017272225		0.040040637	0.022656682	0.016772346	0.022641188",
'
    for k in range(4):
        str += f'{mean[j*4+k]} &pm; {sd[j*4+k]} | '
    print(str) 
    
    j = 4
    str = ' | Linear Probing | '
    for k in range(4):
        str += f'{mean[j*4+k]} &pm; {sd[j*4+k]} | '
    print(str)     
    
    print('\n')
# Out:
# | Fine-Tuning Method | Raw Accuracy | AUROC | F1 | AUPRC |
# | --- | --- | --- | --- | --- |
#  | Finetune | 0.882 &pm; 0.017713774 | 0.697259413 &pm; 0.031201454 | 0.500193115 &pm; 0.039596593 | 0.266987766 &pm; 0.028223554 |
#  | LoRA | 0.861333333 &pm; 0.019160144 | 0.686815923 &pm; 0.039775637 | 0.58871499 &pm; 0.056640226 | 0.26069249 &pm; 0.074624379 |
#  | Generalized Prompt Tuning | 0.875333333 &pm; 0.010022198 | 0.716532224 &pm; 0.033205284 | 0.594736544 &pm; 0.030631316 | 0.269482161 &pm; 0.039237817 |
#  | Prompt Tuning | 0.865333333 &pm; 0.014236104 | 0.727809154 &pm; 0.015578435 | 0.603319784 &pm; 0.042299021 | 0.280745188 &pm; 0.033511886 |
#  | Linear Probing | 0.870666667 &pm; 0.029694743 | 0.740770793 &pm; 0.033805144 | 0.594138785 &pm; 0.02832463 | 0.300161538 &pm; 0.042064855 |
#
#
# | Fine-Tuning Method | Raw Accuracy | AUROC | F1 | AUPRC |
# | --- | --- | --- | --- | --- |
# ...

# %%
input = [

" | Finetune | 0.881 &pm; 0.017 | 0.742 &pm; 0.015 | 0.55 &pm; 0.061 | 0.319 &pm; 0.06 | ",
"| LoRA | 0.84 &pm; 0.037 | 0.681 &pm; 0.013 | 0.592 &pm; 0.024 | 0.248 &pm; 0.064 | ",
"| Generalized Prompt Tuning | 0.859 &pm; 0.023 | 0.708 &pm; 0.033 | 0.598 &pm; 0.045 | 0.256 &pm; 0.043 | ",
"| Prompt Tuning | 0.852 &pm; 0.029 | 0.71 &pm; 0.036 | 0.603 &pm; 0.024 | 0.273 &pm; 0.029 | ",
"| Linear Probing | 0.851 &pm; 0.032 | 0.733 &pm; 0.035 | 0.62 &pm; 0.02 | 0.29 &pm; 0.06 | "
]

# %%
for i in input:
    list = i.split('|')
    # print('|', end='')
    for j in list:
        ks = j.strip()
        for k in ks.split():
            # print(k.replace('.', '', 1).isdigit() )
            # try:
            #     float(k)
            #     print(f'{k:.3f} ', end='')
                
            # except ValueError:
            #     print(f'{k} ', end='')
            
                
            if k.replace('.', '', 1).isdigit():
                # 3 decimal places
                # print(k)
                print(f'{float(k):.3f} ', end='')
            else:
                print(f'{k} ', end='')
        print('|', end='')

    print('\n')
# Out:
# |Finetune |0.881 &pm; 0.017 |0.742 &pm; 0.015 |0.550 &pm; 0.061 |0.319 &pm; 0.060 ||
#
# |LoRA |0.840 &pm; 0.037 |0.681 &pm; 0.013 |0.592 &pm; 0.024 |0.248 &pm; 0.064 ||
#
# |Generalized Prompt Tuning |0.859 &pm; 0.023 |0.708 &pm; 0.033 |0.598 &pm; 0.045 |0.256 &pm; 0.043 ||
#
# |Prompt Tuning |0.852 &pm; 0.029 |0.710 &pm; 0.036 |0.603 &pm; 0.024 |0.273 &pm; 0.029 ||
#
# |Linear Probing |0.851 &pm; 0.032 |0.733 &pm; 0.035 |0.620 &pm; 0.020 |0.290 &pm; 0.060 ||
